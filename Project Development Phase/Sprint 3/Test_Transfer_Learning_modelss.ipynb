# %% [markdown]
# **IBM- PNT2022TMID23190 - Deep Learning Fundus Image Analysis For Early Detection Of Diabetic Retinopathy**

# %% [markdown]
# **SPRINT 3**

# %% [markdown]
# **TESTING THE MODEL**

# %%
#import load_model class for loading h5 file
from tensorflow.keras.models import load_model
#import image class to process the images
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input
import numpy as np

# %% [markdown]
# **LOAD THE SAVED MODEL**

# %%
model=load_model('Updated-xception-diabetic-retinopathy.h5')

# %% [markdown]
# **LOAD RANDOM IMAGE FROM LOCAL SYSTEM FOR TESTING**

# %%
img=image.load_img('/content/Testing2.png',target_size=(299,299))

# %% [markdown]
# **CONVERT IMAGE TO ARRAY FORMAT**

# %%
x=image.img_to_array(img)

# %%
import matplotlib.pyplot as plt

# %%
x.shape
# Out:
# (299, 299, 3)

# %%
import numpy as np
x=np.expand_dims(x,axis=0)
img_data=preprocess_input(x)
img_data.shape
# Out:
# (1, 299, 299, 3)

# %%
model.predict(img_data)
# Out:
# 1/1 [==============================] - 0s 357ms/step
# array([[3.3839223e-12, 4.3068004e-15, 5.9660041e-11, 9.9999404e-01,
#         5.9472959e-06]], dtype=float32)

# %%
output=np.argmax(model.predict(img_data), axis=1)
# Out:
# 1/1 [==============================] - 0s 360ms/step

# %% [markdown]
# **DISPLAY THE TEST IMAGE**

# %%
from IPython.display import display
from PIL import Image
path="/content/Testing2.png"
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2416x1736 at 0x7F9E46E7CB90>

# %%
output==0,output==1,output==2,output==3,output==4
# Out:
# (array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]))

# %% [markdown]
# **DETECTION RESULTS**

# %%
index=['No Diabetic Retinopathy', 'Mild DR', 'Moderate DR', 'Severe DR', 'Proliferative DR']
result = str(index[output[0]])
result
# Out:
# 'Severe DR'
